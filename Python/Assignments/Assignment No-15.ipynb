# %% [markdown]
# #### Q1. What is a database? Differentiate between SQL and NoSQL databases.
# ---->>>
# - A database is a structured collection of data that is organized in such a way that it can be easily accessed, managed, and updated.
# -
# - __SQL__ :
#     - SQL databases, also known as relational databases, store data in tables with predefined schemas. Each table consists of rows and columns, and relationships between tables are established using foreign key constraints.
# - __NoSQL__ :
#     -  NoSQL databases employ various data models, including document-oriented, key-value, wide-column, and graph-based models. They are schema-less or have a dynamic schema, allowing for more flexibility in handling unstructured or semi-structured data.

# %% [markdown]
# #### Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.
# ---->>>
# - DDL stands for Data Definition Language!
# - __CREATE__: The CREATE statement is used to create new database objects such as tables, indexes, views, or schemas.
# - ![Screenshot (86).png](attachment:109c7bfc-8c4c-4c30-8398-6272606767a2.png)
# - __DROP__ : The DROP statement is used to delete existing database objects such as tables, indexes, views, or schemas.
# ![Screenshot (87).png](attachment:d8b9f147-ed0b-4f59-adcb-fb19a01d10ba.png)

# %% [markdown]
# - __ALTER__ : The ALTER statement is used to modify the structure of existing database objects, such as adding, modifying, or dropping columns from a table.
# - ![Screenshot (95).png](attachment:f3a28c37-c359-44db-89e5-a3512221e40d.png)
# - __TRUNCATE__ :  The TRUNCATE statement is used to remove all records from a table, but the table structure and its definition remain intact.

# %%
from IPython.display import Image
Image(r"C:\Users\Admin\Pictures\Screenshots\truncate.png")

# %% [markdown]
# #### Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.
# ---->>>
# - DML stands for Data Manipulation Language
# - __INSERT__: The INSERT statement is used to add new records (rows) into a table.
# ![Screenshot (90).png](attachment:83649f22-e02d-46b0-82d9-be5a92bcff77.png)
# - __UPDATE__: The UPDATE statement is used to modify existing records in a table.
# ![Screenshot (91).png](attachment:87203b8e-424b-47d0-b39c-9c54c5978e0d.png)
# - __DELETE__: The DELETE statement is used to remove one or more records from a table.
# ![Screenshot (92).png](attachment:038c98c3-d224-48fc-a7b1-66e5e23a1d05.png)

# %% [markdown]
# #### Q4. What is DQL? Explain SELECT with an example.
# ---->>>
# - DQL stands for Data Query Language
# - __SELECT__ : he SELECT statement is used to retrieve data from one or more tables in the database.
# ![Screenshot (93).png](attachment:9d3a29de-5783-47ca-ac6a-f29924e7e56e.png)

# %% [markdown]
# #### Q5. Explain Primary Key and Foreign Key.
# ---->>>
# - __Primary Key__ : A Primary Key is a column or a set of columns in a table that uniquely identifies each record (row) in the table.
# - __Foreign Key__ : A Foreign Key is a column or a set of columns in a table that refers to the Primary Key of another table.

# %% [markdown]
# #### Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.
# ---->>>
# - __cursor()__: The cursor() method is used to create a cursor object, which is required to execute SQL queries and fetch results from the database.
# - __execute()__: The execute() method is used to execute SQL queries or statements through the cursor object.
# - ![Screenshot (94).png](attachment:0ce47e97-d493-492d-8282-5ce9649f41ac.png)

# %% [markdown]
# #### Q7. Give the order of execution of SQL clauses in an SQL query.
# ---->>>
# - SQL clauses in the typical order of execution in a query:
# - FROM
# - WHERE
# - GROUP BY
# - HAVING
# - SELECT
# - ORDER BY
# - LIMIT/OFFSET
